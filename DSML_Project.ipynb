# %% [markdown]
# ------------------
# ------------------
# # Hybrid Energy Resource Prediction
# ------------------
# ------------------

# %% [markdown]
# ### Data Preprocessing
# ---------------

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\hybrid energy resource (2).csv")

# %%
data
# Out:
#        Power Usage Effectiveness (PUE) Energy Consumption (kWh)  \
# 0                                  1.4                   20,000
# 1                                  1.8                   21,000
# 2                                  1.6                   19,000
# 3                                  1.6                   17,000
# 4                                  1.3                   37,000
# ...                                ...                      ...
# 25968                              1.4                   32,000
# 25969                              1.8                   30,000
# 25970                              1.5                   49,000
# 25971                              1.7                   16,000
# 25972                              1.4                   47,000
#
#        Renewable Energy Usage (%)  Cooling Efficiency  \
# 0                              90                 1.8
# 1                             100                 1.1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Power Usage Effectiveness (PUE)  25973 non-null  float64
#  1   Energy Consumption (kWh)         25973 non-null  object
#  2   Renewable Energy Usage (%)       25973 non-null  int64
#  3   Cooling Efficiency               25973 non-null  float64
#  4   Total Power Consumption (kW)     25973 non-null  object
#  5   Server Power Consumption (kW)    25973 non-null  int64
#  6   Dynamic Power Usage (kW)         25973 non-null  int64
#  7   CPU Utilization (%)              25973 non-null  int64
#  8   Task Completion Time (ms)        25973 non-null  int64
#  9   SLA Violations                   25973 non-null  int64
#  10  Workload Type                    25973 non-null  object
#  11  Number of Active VMs             25973 non-null  int64
# ...

# %%
data.describe()
# Out:
#        Power Usage Effectiveness (PUE)  Renewable Energy Usage (%)  \
# count                     25973.000000                25973.000000
# mean                          1.500512                   50.162091
# std                           0.177934                   31.575388
# min                           1.200000                    0.000000
# 25%                           1.400000                   20.000000
# 50%                           1.500000                   50.000000
# 75%                           1.700000                   80.000000
# max                           1.800000                  100.000000
#
#        Cooling Efficiency  Server Power Consumption (kW)  \
# count        25973.000000                   25973.000000
# mean             1.399823                     109.846764
# std              0.234768                      54.882858
# min              1.000000                      20.000000
# 25%              1.200000                      60.000000
# ...

# %%
data.head(10)
# Out:
#    Power Usage Effectiveness (PUE) Energy Consumption (kWh)  \
# 0                              1.4                   20,000
# 1                              1.8                   21,000
# 2                              1.6                   19,000
# 3                              1.6                   17,000
# 4                              1.3                   37,000
# 5                              1.3                    9,000
# 6                              1.2                   31,000
# 7                              1.7                    5,000
# 8                              1.6                   48,000
# 9                              1.6                   34,000
#
#    Renewable Energy Usage (%)  Cooling Efficiency  \
# 0                          90                 1.8
# 1                         100                 1.1
# 2                          70                 1.5
# 3                          70                 1.5
# ...

# %%
data.tail(10)
# Out:
#        Power Usage Effectiveness (PUE) Energy Consumption (kWh)  \
# 25963                              1.4                   38,000
# 25964                              1.2                   38,000
# 25965                              1.8                   27,000
# 25966                              1.2                   23,000
# 25967                              1.6                   36,000
# 25968                              1.4                   32,000
# 25969                              1.8                   30,000
# 25970                              1.5                   49,000
# 25971                              1.7                   16,000
# 25972                              1.4                   47,000
#
#        Renewable Energy Usage (%)  Cooling Efficiency  \
# 25963                           0                 1.2
# 25964                          80                 1.7
# 25965                          90                 1.5
# ...

# %%
data.isnull()
# Out:
#        Power Usage Effectiveness (PUE)  Energy Consumption (kWh)  \
# 0                                False                     False
# 1                                False                     False
# 2                                False                     False
# 3                                False                     False
# 4                                False                     False
# ...                                ...                       ...
# 25968                            False                     False
# 25969                            False                     False
# 25970                            False                     False
# 25971                            False                     False
# 25972                            False                     False
#
#        Renewable Energy Usage (%)  Cooling Efficiency  \
# 0                           False               False
# 1                           False               False
# ...

# %%
data.isnull().sum()
# Out:
# Power Usage Effectiveness (PUE)    0
# Energy Consumption (kWh)           0
# Renewable Energy Usage (%)         0
# Cooling Efficiency                 0
# Total Power Consumption (kW)       0
# Server Power Consumption (kW)      0
# Dynamic Power Usage (kW)           0
# CPU Utilization (%)                0
# Task Completion Time (ms)          0
# SLA Violations                     0
# Workload Type                      0
# Number of Active VMs               0
# Energy Strategy                    0
# Energy Savings (%)                 0
# dtype: int64

# %%
data.dtypes
# Out:
# Power Usage Effectiveness (PUE)    float64
# Energy Consumption (kWh)            object
# Renewable Energy Usage (%)           int64
# Cooling Efficiency                 float64
# Total Power Consumption (kW)        object
# Server Power Consumption (kW)        int64
# Dynamic Power Usage (kW)             int64
# CPU Utilization (%)                  int64
# Task Completion Time (ms)            int64
# SLA Violations                       int64
# Workload Type                       object
# Number of Active VMs                 int64
# Energy Strategy                     object
# Energy Savings (%)                   int64
# dtype: object

# %%
data["Workload Type"].value_counts()
# Out:
# Workload Type
# Mixed            8674
# Compute-heavy    8672
# I/O heavy        8627
# Name: count, dtype: int64

# %%
data['Energy Strategy'].value_counts()
# Out:
# Energy Strategy
# Non-renewable      8726
# Renewable-first    8635
# Hybrid             8612
# Name: count, dtype: int64
